# %% [markdown]
# ### 4기 1주차 과제 - 유재성

# %% [markdown]
# ### Q1. 자판기 쿠폰 사용하는 SSMoney 클래스 만들기
#
#  - 자판기에서 초코릿 바를 개당 1원에 살 수 있다고 가정하자. 모든 초콜릿 바 안에는 쿠폰이 들어있다. 당신은 자판기에서 7개의 쿠폰으로 1개의 초코릿 바를 돌려 받을 수 있다. 당신은 쿠폰으로 돌려받은 초콜릿을 포함해서 몇 개의 초콜릿 바를 먹을 수 있을 지 알고 싶다. 당신이 n원을 가지고 있다고 가정한다. n원과 쿠폰을 사용하여 당신이 얻을 수 있는 초코바의 개수와 남은 쿠폰의 개수를 출력하는 기능을 포함하는 SSMoney 클래스를 작성하시오.
#
#
#  - 예) money=20을 가지고 있다면, 자판기에서 초코바를 산 후 에는 ☆초콜릿 23개, 쿠폰 2개☆를 가지고 있어야함.

# %% [markdown]
#  - (설계)
#
# ```
# 1. 목표
#  : 자판기에서 초코릿 바를 살 수 있는 기능이 가능한 클래스 만들기 (클래스 이름 : SSMoney)
# 2. 필요기능
#  - money 정하기
#  - cho 정하기
#  - cou 정하기
#  - money 값 리턴
#  - cho 값 리턴
#  - cou 값 리턴
#  - SSMoney 가 가지고 있는 돈으로 얻을 수 있는 초코바와 쿠폰의 개수 계산하기
#  - SSMoney의 현재 money,cho,cou 출력하기
#  3. 필요변수
#  - 돈, 초코바의 개수, 쿠폰의 개수를 입력받을 객체변수 money, cho, cou
#  ※ 객체에 생성되는 객체만의 변수를 객체변수라고 부른다.
# 4. 필요함수
#  - money 정하기 (함수 이름 : set_money)
#  - cho 정하기  (함수 이름 : set_cho)
#  - cou 정하기(함수 이름 : set_cou)
#  - money 값 리턴(함수 이름 : get_money)
#  - cho 값 리턴(함수 이름 : get_cho)
#  - cou 값 리턴(함수 이름 : get_cou)
#  - SSMoney 가 가지고 있는 돈으로 얻을 수 있는 초코바와 쿠폰의 개수 계산하기(함수 이름 : buy_cho)
#  - SSMoney의 현재 money, cho, cou 출력하기(함수이름 : show_data)
# ```

# %%
class SSMoney:
    def __init__(self, money, cou, cho):
        self.money = money
        self.cou = cou
        self.cho = cho
        
    def set_money(self, money):
        self.money = money
    
    def set_cho(self, cho):
        self.cho = cho
    
    def set_cou(self, cou):
        self.cou = cou
     
    def get_money(self):
        return self.money
    
    def get_cho(self):
        return self.cho
    
    def get_cou(self):
        return self.cou
    
    def buy_cho(self):
        while(self.money>0):    # money가 0이 되면 종료
            self.money -= 1     # money 1 차감
            self.cho += 1       # cho 1 추가
            self.cou += 1       # cou 1 추가
            if self.cou == 7:   # cou가 7개 일 경우 초콜릿 1개 추가
                self.set_cou(1) # 쿠폰으로 받은 초콜릿에도 쿠폰이 있으므로 
                                # cou를 0이 아닌 1로 설정
                self.cho += 1

    def show_data(self): # 초콜릿 구매 후 결과물 확인
        print('현재 돈: {0}원\n현재 쿠폰: {1}개\n현재 초콜릿: {2}개'.
              format(self.get_money(), self.get_cou(), self.get_cho()))

# %%
a = SSMoney(20, 0 ,0)
a.buy_cho()
a.show_data()
# Out:
# 현재 돈: 0원
# 현재 쿠폰: 2개
# 현재 초콜릿: 23개

# %% [markdown]
# ## Q2
# The following code loads the olympics dataset (olympics.csv), which was derrived from the Wikipedia entry on [All Time Olympic Games Medals](https://en.wikipedia.org/wiki/All-time_Olympic_Games_medal_table), and does some basic data cleaning.
#
# The columns are organized as # of Summer games, Summer medals, # of Winter games, Winter medals, total # number of games, total # of medals. Use this dataset to answer the questions below.

# %%
import pandas as pd

df = pd.read_csv('olympics.csv', index_col=0, skiprows=1)

for col in df.columns:
    if col[:2]=='01':
        df.rename(columns={col:'Gold'+col[4:]}, inplace=True)
    if col[:2]=='02':
        df.rename(columns={col:'Silver'+col[4:]}, inplace=True)
    if col[:2]=='03':
        df.rename(columns={col:'Bronze'+col[4:]}, inplace=True)
    if col[:1]=='№':
        df.rename(columns={col:'#'+col[1:]}, inplace=True)

names_ids = df.index.str.split('\s\(') # split the index by '('

df.index = names_ids.str[0] # the [0] element is the country name (new index) 
df['ID'] = names_ids.str[1].str[:3] # the [1] element is the abbreviation or ID (take first 3 characters from that)

df = df.drop('Totals')
df.head()
# Out:
#              # Summer  Gold  Silver  Bronze  Total  # Winter  Gold.1  \
# Afghanistan        13     0       0       2      2         0       0
# Algeria            12     5       2       8     15         3       0
# Argentina          23    18      24      28     70        18       0
# Armenia             5     1       2       9     12         6       0
# Australasia         2     3       4       5     12         0       0
#
#              Silver.1  Bronze.1  Total.1  # Games  Gold.2  Silver.2  Bronze.2  \
# Afghanistan         0         0        0       13       0         0         2
# Algeria             0         0        0       15       5         2         8
# Argentina           0         0        0       41      18        24        28
# Armenia             0         0        0       11       1         2         9
# Australasia         0         0        0        2       3         4         5
#
#              Combined total   ID
# Afghanistan               2  AFG
# ...

# %% [markdown]
# ## Q 2-1
# 총 금메달 수에 비해 여름 금메달 수와 겨울 금메달 수 사이에 가장 큰 차이가 있는 나라는 어디일까.
#
# $$\frac{Summer~Gold - Winter~Gold}{Total~Gold}$$
#
# 여름과 겨울에 최소 1개의 금메달을 획득한 국가만 포함된다.
#
# *이 기능은 단일 문자열 값을 반환해야 한다.*

# %%
# 여름 금메달 수 (Gold)와 겨울 금메달 수 (Gold.1)가 1보다 큰 행 필터링
df_filtered = df.loc[(df['Gold']>0) & (df['Gold.1']>0)]
# 금메달 비율 계산
gold_ratio = (df_filtered['Gold'] - df_filtered['Gold.1']) / df_filtered['Gold.2']
# 가장 큰 금메달 비율을 가진 행의 인덱스 반환
gold_ratio.idxmax()
# Out:
# 'Bulgaria'

# %%
gold_ratio
# Out:
# Australia                 0.930556
# Austria                  -0.532468
# Belarus                   0.333333
# Belgium                   0.947368
# Bulgaria                  0.961538
# Canada                   -0.024793
# China                     0.887324
# Croatia                   0.200000
# Czech Republic            0.333333
# Czechoslovakia            0.921569
# Estonia                   0.384615
# Finland                   0.412587
# France                    0.733906
# Germany                   0.380952
# United Team of Germany    0.555556
# East Germany              0.593750
# West Germany              0.671642
# Great Britain             0.918699
# Italy                     0.685106
# Japan                     0.857143
# Kazakhstan                0.882353
# South Korea               0.514019
# Netherlands               0.350877
# Norway                   -0.356322
# Poland                    0.828571
# Russia                    0.458564
# Soviet Union              0.670190
# ...

# %% [markdown]
# bulgaria가 실제로 가장 많이 차이남을 알 수 있다.

# %% [markdown]
# ## Q3
# For the next set of questions, we will be using census data from the [United States Census Bureau](http://www.census.gov/popest/data/counties/totals/2015/CO-EST2015-alldata.html). Counties are political and geographic subdivisions of states in the United States. This dataset contains population data for counties and states in the US from 2010 to 2015. [See this document](http://www.census.gov/popest/data/counties/totals/2015/files/CO-EST2015-alldata.pdf) for a description of the variable names.
#
# ## Q3-1
# census.csv파일을 census_df 라는 변수명으로 불러오십시오.

# %%
census_df = pd.read_csv('census.csv')
census_df.head()
# Out:
#    SUMLEV  REGION  DIVISION  STATE  COUNTY   STNAME         CTYNAME  \
# 0      40       3         6      1       0  Alabama         Alabama
# 1      50       3         6      1       1  Alabama  Autauga County
# 2      50       3         6      1       3  Alabama  Baldwin County
# 3      50       3         6      1       5  Alabama  Barbour County
# 4      50       3         6      1       7  Alabama     Bibb County
#
#    CENSUS2010POP  ESTIMATESBASE2010  POPESTIMATE2010  ...  RDOMESTICMIG2011  \
# 0        4779736            4780127          4785161  ...          0.002295
# 1          54571              54571            54660  ...          7.242091
# 2         182265             182265           183193  ...         14.832960
# 3          27457              27457            27341  ...         -4.728132
# 4          22915              22919            22861  ...         -5.527043
#
#    RDOMESTICMIG2012  RDOMESTICMIG2013  RDOMESTICMIG2014  RDOMESTICMIG2015  \
# ...

# %% [markdown]
# ## Q3-2
#
# 이 자료 파일에서 미국은 "REGION" 열을 사용하여 4개의 지역으로 분할된다.
#
# 이름이 'Washington'으로 시작하고 POPESTIMATE2015가 POPESTIMATE 2014보다 크고 지역 1 또는 2에 속하는 카운티를 찾는 쿼리를 생성하십시오.
#
# *이 함수는 5x2 데이터프레임과 열 = ['STNAME', 'CTYNAME'] 및 census_df(sorted ascending by index)와 동일한 인덱스를 반환해야 한다.*

# %% [markdown]
# 먼저 필요로 하는 열들이 어떤 값으로 구성되어 있는지 확인해보았다.

# %%
print(census_df['REGION'].unique(),'\n')
print(census_df['STNAME'].unique(),'\n')
print(census_df['CTYNAME'].unique(),'\n')
# Out:
# [3 4 1 2]
#
# ['Alabama' 'Alaska' 'Arizona' 'Arkansas' 'California' 'Colorado'
#  'Connecticut' 'Delaware' 'District of Columbia' 'Florida' 'Georgia'
#  'Hawaii' 'Idaho' 'Illinois' 'Indiana' 'Iowa' 'Kansas' 'Kentucky'
#  'Louisiana' 'Maine' 'Maryland' 'Massachusetts' 'Michigan' 'Minnesota'
#  'Mississippi' 'Missouri' 'Montana' 'Nebraska' 'Nevada' 'New Hampshire'
#  'New Jersey' 'New Mexico' 'New York' 'North Carolina' 'North Dakota'
#  'Ohio' 'Oklahoma' 'Oregon' 'Pennsylvania' 'Rhode Island' 'South Carolina'
#  'South Dakota' 'Tennessee' 'Texas' 'Utah' 'Vermont' 'Virginia'
#  'Washington' 'West Virginia' 'Wisconsin' 'Wyoming']
#
# ['Alabama' 'Autauga County' 'Baldwin County' ... 'Uinta County'
#  'Washakie County' 'Weston County']

# %% [markdown]
# REGION 열은 1,2,3,4 네 개의 값으로 이루어져 있다.
#
# STNAME 열에서 Washington으로 시작하는 문자열은 Washington만 존재한다.
#
# 먼저 census_df에 인덱스를 만들어주기 위해 SUMLEV열에 번호를 매겨준다.

# %%
for i in range(len(census_df.SUMLEV)):
    census_df['SUMLEV'][i] = i

# SUMLEV 열을 인덱스로 지정
census_df.set_index('SUMLEV', inplace=True)
# census_df 5행 출력
census_df.head()
# Out:
# C:\ProgramData\Anaconda3\envs\tens_2g\lib\site-packages\ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#         REGION  DIVISION  STATE  COUNTY   STNAME         CTYNAME  \
# SUMLEV
# 0            3         6      1       0  Alabama         Alabama
# 1            3         6      1       1  Alabama  Autauga County
# 2            3         6      1       3  Alabama  Baldwin County
# 3            3         6      1       5  Alabama  Barbour County
# 4            3         6      1       7  Alabama     Bibb County
#
#         CENSUS2010POP  ESTIMATESBASE2010  POPESTIMATE2010  POPESTIMATE2011  \
# SUMLEV
# 0             4779736            4780127          4785161          4801108
# 1               54571              54571            54660            55253
# ...

# %% [markdown]
# 먼저 STNAME이 Washington인 열들을 살펴보았다.

# %%
census_df[census_df['STNAME']=='Washington']
# Out:
#         REGION  DIVISION  STATE  COUNTY      STNAME              CTYNAME  \
# SUMLEV
# 3000         4         9     53       0  Washington           Washington
# 3001         4         9     53       1  Washington         Adams County
# 3002         4         9     53       3  Washington        Asotin County
# 3003         4         9     53       5  Washington        Benton County
# 3004         4         9     53       7  Washington        Chelan County
# 3005         4         9     53       9  Washington       Clallam County
# 3006         4         9     53      11  Washington         Clark County
# 3007         4         9     53      13  Washington      Columbia County
# 3008         4         9     53      15  Washington       Cowlitz County
# 3009         4         9     53      17  Washington       Douglas County
# 3010         4         9     53      19  Washington         Ferry County
# 3011         4         9     53      21  Washington      Franklin County
# ...

# %% [markdown]
# STNAME열이 Washington일 때 REGION이 모두 4로 문제에서 요구하는 (REGION = 1 or 2)를 만족하지 못함을 알 수 있었다.
#
# 따라서 CTYNAME열에 Washington을 포함하는 값이 있는지 살펴보았다.

# %%
census_df[census_df['CTYNAME'].str.contains('Washington')]
# Out:
#         REGION  DIVISION  STATE  COUNTY          STNAME            CTYNAME  \
# SUMLEV
# 65           3         6      1     129         Alabama  Washington County
# 186          3         7      5     143        Arkansas  Washington County
# 311          4         8      8     121        Colorado  Washington County
# 396          3         5     12     133         Florida  Washington County
# 547          3         5     13     303         Georgia  Washington County
# 607          4         8     16      87           Idaho  Washington County
# 703          2         3     17     189        Illinois  Washington County
# 799          2         3     18     175         Indiana  Washington County
# 896          2         4     19     183            Iowa  Washington County
# 1005         2         4     20     201          Kansas  Washington County
# 1125         3         6     21     229        Kentucky  Washington County
# ...

# %% [markdown]
# 32개의 행이 washington으로 시작함을 알 수 있었다. 또한 REGION도 1부터 4까지 값이 존재했기 때문에 CTYNAME으로 쿼리문을 작성하였다.

# %%
# 이름이 'Washington'으로 시작하고 POPESTIMATE2015가 POPESTIMATE 2014보다 크고 지역 1 또는 2에 속하는 카운티를 찾는 쿼리를 생성
filtered_cencus_df = census_df[(census_df['CTYNAME'].str.contains('Washington')) & (census_df['POPESTIMATE2015'] > census_df['POPESTIMATE2014']) & (census_df['REGION']==1) |
                               (census_df['CTYNAME'].str.contains('Washington')) & (census_df['POPESTIMATE2015'] > census_df['POPESTIMATE2014']) & (census_df['REGION']==2)]
# 이 함수는 5x2 데이터프레임과 열 = ['STNAME', 'CTYNAME'] 및 census_df(sorted ascending by index)와 동일한 인덱스를 반환해야 한다.
filtered_cencus_df = filtered_cencus_df[['STNAME', 'CTYNAME']]

# %%
filtered_cencus_df
# Out:
#               STNAME            CTYNAME
# SUMLEV
# 896             Iowa  Washington County
# 1419       Minnesota  Washington County
# 2345    Pennsylvania  Washington County
# 2355    Rhode Island  Washington County
# 3163       Wisconsin  Washington County

# %%
census_df.iloc[[896, 1419, 2345, 2355, 3163]][['STNAME', 'CTYNAME']]
# Out:
#               STNAME            CTYNAME
# SUMLEV
# 896             Iowa  Washington County
# 1419       Minnesota  Washington County
# 2345    Pennsylvania  Washington County
# 2355    Rhode Island  Washington County
# 3163       Wisconsin  Washington County

# %% [markdown]
# census_df의 인덱스와 filtered_df의 인덱스가 동일한 것을 알 수 있다.
